# %%
import openai
from openai import OpenAI
import fitz

# %%
import pathlib
from pathlib import Path

# %%
paper_name = "blms.70013"
fullpath = f"../data/BLMC/{paper_name}.pdf"

# %%
from dotenv import load_dotenv
import os
load_dotenv()

client = OpenAI (
    api_key = os.getenv("OPENAI_API_KEY")
)

# %%
filepath=Path(fullpath)
def extract_text_from_pdf(path):
    doc = fitz.open(path)
    return "\n\n".join(page.get_text() for page in doc)

pdf_text = extract_text_from_pdf(filepath)

# %%
import json
schema = json.loads(Path("./prompts/PaperStructure.json").read_text())

prompt = (
    "Write the attached mathematics paper as a structured JSON file in the given JSON schema format. "
    "Use LaTeX for formulas but otherwise use markdown. The schema is as follows:\n\n"
    + str(schema)
)

# %%
response = client.chat.completions.create(
    model="o1",
    messages=[
        {"role": "system", "content": "You are an assistant that converts academic papers into structured JSON. Strictly follow the JSON schema."},
        {"role": "user", "content": prompt},
        {"role": "user", "content": pdf_text},
    ],
)

# %%
paper_json_out = response.choices[0].message.content
print(paper_json_out)
# Out:
# {
#   "document": [
#     {
#       "title": "Distinguishing internally club and approachable on an Infinite interval"
#     },
#     {
#       "abstract": "Krueger showed that PFA implies that for all regular Θ ≥ ℵ₂, there are stationarily many [H(Θ)]^(ℵ₁) that are internally club but not internally approachable. From countably many Mahlo cardinals, we force a model in which, for all positive n < ω and Θ ≥ ℵₙ₊₁, there is a stationary subset of [H(Θ)]^(ℵₙ) consisting of sets that are internally club but not internally approachable. The theorem is obtained using a new variant of Mitchell forcing. This answers questions of Krueger."
#     },
#     {
#       "metadata": {
#         "authors": [
#           {
#             "label": "Hannes Jakob",
#             "affiliation": "Mathematisches Institut, University of Freiburg, Freiburg im Breisgau, Germany"
#           },
#           {
#             "label": "Maxwell Levine",
#             "affiliation": "Mathematisches Institut, University of Freiburg, Freiburg im Breisgau, Germany"
#           }
#         ],
#         "keywords": [
#           "internally club",
#           "approachable",
#           "Mahlo cardinals",
#           "Mitchell forcing"
#         ],
#         "msc_codes": [
#           "03E35",
#           "03E55"
#         ],
#         "publication_date": "2025-01-09",
#         "source": "Bulletin of the London Mathematical Society, DOI: 10.1112/blms.70013"
#       }
#     },
#     {
#       "label": "sec:intro",
#       "header": "1 Introduction",
#       "level": 1,
#       "content": [
#         {
#           "Paragraph": {
#             "text": "Skolem originally regarded what is now known as the Löwenheim–Skolem theorem as an illustration of the paradoxical nature of infinite cardinals, particularly when uncountable cardinals are considered as elements of countable models. Despite this original motivation, this theorem is nowadays used as an essential tool for proving numerous positive results in combinatorial set theory. Foreman and Todorčević deepened the study of the Löwenheim–Skolem theorem and introduced variations of the concept of internal approachability, which considers the internal composition of elementary submodels [4]. We are left with a situation in which the formal construction of sets gives rise to its own sort of geometry in which subtle distinctions can be made regarding the structure of such models."
#           }
#         },
#         {
#           "Paragraph": {
#             "text": "Following the work of Foreman and Todorčević, Krueger wrote a series of papers exploring variations of internal approachability, in particular proving that the variations are distinct [10]. He showed that these distinctions can be obtained using mixed-support iterations, which resemble the forcings Mitchell used to obtain the tree property at double successor cardinals. Notable developments in the study of the tree property pertain to obtaining the tree property simultaneously on long intervals of cardinals, and this area of research requires analyses of variants of Mitchell’s forcing. In this spirit, Krueger raised the question of whether these properties could be separated for successive cardinals, or even an infinite sequence of cardinals [12]. We studied the case in which internally stationary is distinguished from internally club by using forcings that accomplish the work of mixed support iterations while more explicitly resembling Mitchell’s forcing [7, 13]."
#           }
#         },
#         {
#           "Paragraph": {
#             "text": "In this paper, we will demonstrate the robustness of this idea by addressing the separation of internally club from internally approachable. We introduce a new version of Mitchell forcing, for which we must consider somewhat elaborate termspaces. The benefit is derived from having an Abraham-style projection analysis. We hope that this concept will be useful for points in the literature where mixed support iterations are called for (see [5], for example)."
#           }
#         },
#         {
#           "Paragraph": {
#             "text": "The concepts we study here are framed in terms of the notion of stationarity for spaces of the form [X]≤μ, which was formulated by Jech (see [9]). For a regular cardinal μ, we say that some N ∈ [X]≤μ is:\n• internally unbounded if [N]<μ ∩ N is unbounded in [N]<μ,\n• internally stationary if [N]<μ ∩ N is stationary in [N]<μ,\n• internally club if [N]<μ ∩ N contains a club in [N]<μ,\n• internally approachable if there is a continuous sequence ⟨Nᵢ : i < μ⟩ consisting of elements of [N]<μ such that for all i < μ, ⟨Nⱼ : j ≤ i⟩ ∈ N and N = ⋃(i < μ) Nᵢ."
#           }
#         },
#         {
#           "Paragraph": {
#             "text": "For clarity, let ICNIA(Θ, μ) be the statement that Θ ≥ μ⁺ and that there exist stationarily many N ∈ [H(Θ)]≤μ that are internally club but not internally approachable. If μ is singular or μ = ω, this property fails in trivial ways, as described in the text. Krueger showed that PFA implies ICNIA(Θ, ℵ₁) for all Θ ≥ ℵ₂ and later showed that ICNIA(μ⁺, μ) is consistent from a Mahlo cardinal for regular μ [10, 12]. Here, we extend that result to a whole infinite interval of cardinals."
#           }
#         }
#       ]
#     },
#     {
#       "label": "thm:1.1",
#       "header": "Theorem",
#       "claim": "Assume that there are countably many Mahlo cardinals in V. Then, there is a forcing extension in which, for all 1 ≤ n < ω, ICNIA(Θ, ℵₙ) holds for all Θ ≥ ℵₙ₊₁."
#     },
#     {
#       "label": "sec:2",
#       "header": "2 The new forcing",
#       "level": 1,
#       "content": [
#         {
#           "Paragraph": {
#             "text": "In this section, we will define the new forcing and present a simple application before moving on to the proof of our main theorem."
#           }
#         },
#         {
#           "label": "sec:2.1",
#           "header": "2.1 Defining the forcing",
#           "level": 2,
#           "content": [
#             {
#               "Definition": {
#                 "label": "def:2.1",
#                 "header": "Definition",
#                 "definition": "Let μ, δ be cardinals and S ⊆ [X]<μ be stationary for some set X. The chain forcing P(S) consists of closed sequences of length < μ through S, that is, sequences s such that dom(s) is a successor ordinal below μ, s(α) ∈ S for all α in dom(s), and s(γ) = ⋃(α < γ) s(α) for all limit γ in dom(s). The poset P(S) is used because it allows us to collapse |X| while retaining both the approximation property and the clubness of the “old” sets."
#               }
#             },
#             {
#               "Lemma": {
#                 "label": "fact:2.2",
#                 "header": "Lemma",
#                 "claim": "Let μ ≤ δ be cardinals and S ⊆ [H(δ)]<μ be stationary.\n1) P(S) adds an increasing and continuous sequence of elements ⟨Sᵢ : i < μ⟩ of S with union H(δ)⟰, thus collapsing δ to have cardinality μ.\n2) If 2^δ = δ, then P(S) has cardinality δ and therefore is δ⁺-c.c.\nHence, P(S) is instrumental in forcing certain collapses."
#               }
#             },
#             {
#               "Paragraph": {
#                 "text": "We next define our Mitchell forcing so that it isolates the needed structure. To maintain certain covering properties, we require that we work in an outer model with ι-Knaster for certain cardinals."
#               }
#             },
#             {
#               "Definition": {
#                 "label": "def:2.4",
#                 "header": "Definition",
#                 "definition": "Let τ < μ < κ be cardinals in V such that τ <τ = τ and κ is inaccessible. Let W ⊆ V be models of ZFC containing the ordinals such that Add(τ, κ)ᵂ is μ-Knaster. Then we define M⊕(τ, μ, κ, W) in V to be the poset consisting of pairs (p, q) such that:\n(1) p ∈ Add(τ, κ)ᵂ,\n(2) q is a < μ-sized function on κ such that:\n    (a) for each α ∈ dom(q), α = δ + 1 for an inaccessible cardinal δ,\n    (b) q(α) is an (Add(τ, α))ᵂ-name for an element in the chain forcing P([H(δ)]<μ ∩ V[(Add(τ, δ))ᵂ]).\nWe let (p′, q′) ≤ (p, q) if:\n(1) p′ ≤ p in Add(τ, κ)ᵂ,\n(2) dom(q′) ⊇ dom(q) and for all α ∈ dom(q), p′ ↾ α ⊩ q′(α) ≤ q(α)."
#               }
#             },
#             {
#               "Paragraph": {
#                 "text": "This poset M⊕(τ, μ, κ, W) behaves in many ways like the usual Mitchell forcing. We also define its termspace T(M⊕(τ, μ, κ, W)), denoted T, consisting of partial functions that name conditions in the chain forcing for successors of inaccessible cardinals."
#               }
#             },
#             {
#               "Lemma": {
#                 "label": "lem:2.7",
#                 "header": "Lemma",
#                 "claim": "Let τ < μ < δ be cardinals such that τ <τ = τ. Then, the term forcing T(M⊕(τ, μ, κ, W)) is strongly μ-strategically closed."
#               }
#             },
#             {
#               "Paragraph": {
#                 "text": "The key idea is to show that the direct extension ordering on Add(τ, γ + 1) ∗ P([δ]<μ ∩ V[Add(τ, γ)]) is strongly μ-strategically closed. We exploit the fact that Add(τ, γ + 1) remains μ-Knaster, allowing us to define a winning strategy in the completeness game."
#               }
#             },
#             {
#               "Proposition": {
#                 "label": "prop:2.8",
#                 "header": "Proposition",
#                 "claim": "Let M⊕ = M⊕(τ, μ, κ, W).\n1) M⊕ is κ-Knaster.\n2) M⊕ is a projection of the product Add(τ, κ)ᵂ × T(M⊕(τ, μ, κ, W)).\n3) M⊕ forces κ = 2^τ = μ⁺ = τ⁺⁺."
#               }
#             },
#             {
#               "Lemma": {
#                 "label": "lem:2.9",
#                 "header": "Lemma",
#                 "claim": "M⊕(τ, μ, κ, W) has the < μ-approximation property."
#               }
#             },
#             {
#               "Paragraph": {
#                 "text": "The proof uses iteration-like arguments and is based on ideas by Usuba and Unger, mixing names cleverly to move disagreements into the first coordinate and ensuring no new < μ-sequences appear in the extension."
#               }
#             }
#           ]
#         },
#         {
#           "label": "sec:2.2",
#           "header": "2.2 Considering quotients",
#           "level": 2,
#           "content": [
#             {
#               "Paragraph": {
#                 "text": "As with standard Mitchell forcing, we can define quotient forcings for M⊕(τ, μ, κ, W). The main points are that these quotients preserve the crucial closure and approximation properties needed for our constructions."
#               }
#             },
#             {
#               "Definition": {
#                 "label": "def:2.11",
#                 "header": "Definition",
#                 "definition": "Let τ < μ < ν < κ be cardinals such that Add(τ, κ)ᵂ is μ-Knaster. Let G ⊆ M⊕(τ, μ, ν, W) be a generic filter. In V[G], define M⊕(G, τ, μ, κ \\ ν, W) analogously to M⊕(τ, μ, κ, W) but allowing conditions only on κ \\ ν and interpreting chain forcings for inaccessible successors lying above ν."
#               }
#             },
#             {
#               "Lemma": {
#                 "label": "lem:2.12",
#                 "header": "Lemma",
#                 "claim": "There is a dense embedding from M⊕(τ, μ, κ, W) into M⊕(τ, μ, ν, W) ∗ M⊕(G, τ, μ, κ \\ ν, W)."
#               }
#             },
#             {
#               "Paragraph": {
#                 "text": "Similarly, the forcing M⊕(G, τ, μ, κ \\ ν, W) remains κ-Knaster and preserves the < μ-approximation property in extensions. This allows us to extend Mitchell-style arguments to intervals of cardinals."
#               }
#             }
#           ]
#         },
#         {
#           "label": "sec:2.3",
#           "header": "2.3 Distinguishing internally club and approachable for a single cardinal",
#           "level": 2,
#           "content": [
#             {
#               "Paragraph": {
#                 "text": "We now show that M⊕(τ, μ, κ, V) forces ICNIA(κ, μ) to hold at κ = μ⁺. In fact, we can slightly enhance it to show the stronger ICNIA+(Θ, μ)."
#               }
#             },
#             {
#               "Definition": {
#                 "label": "def:rich",
#                 "header": "Definition",
#                 "definition": "Let κ be a Mahlo cardinal and let Θ be sufficiently large and regular. A model M ≺ H(Θ) is called rich with respect to κ if:\n1) κ ∈ M,\n2) κ̄ := M ∩ κ < κ,\n3) κ̄ is an inaccessible cardinal,\n4) |M| = κ̄,\n5) M is closed under < κ̄-sequences."
#               }
#             },
#             {
#               "Lemma": {
#                 "label": "fact:2.17",
#                 "header": "Lemma",
#                 "claim": "If κ is Mahlo and Θ is sufficiently large, then for all a ∈ [H(Θ)]<κ, there is an M ≺ H(Θ) with a ⊆ M and M rich with respect to κ."
#               }
#             },
#             {
#               "Theorem": {
#                 "label": "thm:2.18",
#                 "header": "Theorem",
#                 "claim": "M⊕(τ, μ, κ, V) forces that there exist stationarily many N ∈ [H(κ)]≤μ such that N is internally club but not internally approachable."
#               }
#             },
#             {
#               "Paragraph": {
#                 "text": "The proof constructs a club set in the forcing extension and shows that a suitable rich submodel remains internally club but fails approachability by carefully analyzing its Mostowski collapse and how the forcing behaves with respect to approximation properties."
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "label": "sec:3",
#       "header": "3 Distinguishing internally club and approachable on an infinite interval",
#       "level": 1,
#       "content": [
#         {
#           "label": "sec:3.1",
#           "header": "3.1 Preservation of the distinction",
#           "level": 2,
#           "content": [
#             {
#               "Paragraph": {
#                 "text": "We now discuss conditions under which ICNIA(Θ, ℵₙ) is preserved by certain well-behaved forcings, leading to the core argument of our main theorem."
#               }
#             },
#             {
#               "Definition": {
#                 "label": "def:3.1",
#                 "header": "Definition",
#                 "definition": "ICNIA+(Θ, μ) is the statement that Θ ≥ μ⁺ and there exist stationarily many N ∈ [H(Θ)]≤μ such that:\n1) N is internally club;\n2) There is no sequence (Xᵢ)ᵢ<μ of elements of [Θ]<μ with ►(Xᵢ)ᵢ<μ = N ∩ Θ and (Xᵢ)ᵢ<j ∈ N for all j < μ (i.e., N is not ordinal-internally approachable)."
#               }
#             },
#             {
#               "Proposition": {
#                 "label": "prop:3.2",
#                 "header": "Proposition",
#                 "claim": "Suppose V ⊆ W is a forcing extension by a < μ⁺-distributive forcing. If ICNIA+(Θ, μ) holds in W, then ICNIA+(Θ, μ) holds in V."
#               }
#             }
#           ]
#         },
#         {
#           "label": "sec:3.2",
#           "header": "3.2 Proving the main theorem",
#           "level": 2,
#           "content": [
#             {
#               "Paragraph": {
#                 "text": "We turn to the proof of Theorem 1.1. Suppose (κₙ)ₙ∈ω is a sequence of Mahlo cardinals. We iterate with full support, building an iteration I = ⟨ℙₙ : n < ω⟩, carefully ensuring that each step preserves Mahlo properties and extends the arguments of Section 2 to long intervals of cardinals."
#               }
#             },
#             {
#               "Lemma": {
#                 "label": "lem:3.6",
#                 "header": "Lemma",
#                 "claim": "Let τ < μ < κ be cardinals such that τ <τ = τ, μ = μ<μ, and κ is Mahlo. If γ is any ordinal, M⊕(τ, μ, κ, W) × Add(μ, γ) forces ICNIA+(Θ, μ) for all regular Θ ≥ κ."
#               }
#             },
#             {
#               "Paragraph": {
#                 "text": "The proof refines the argument of Theorem 2.18, working in a product with an additional Add(μ, γ) factor. One exploits the knaster property of the relevant forcing pieces, ensuring no new ≤ μ-sequences appear."
#               }
#             },
#             {
#               "Paragraph": {
#                 "text": "Combining these results via standard projection analysis yields that, at each stage, one can preserve the statement ICNIA+(Θ, κₙ) for successor cardinals of a Mahlo sequence. By carefully bookkeeping across the entire iteration, we obtain the final statement ICNIA(Θ, ℵₙ) for all n and all Θ ≥ ℵₙ₊₁."
#               }
#             },
#             {
#               "Remark": {
#                 "label": "rem:3.10",
#                 "header": "Remark",
#                 "remark": "A related construction using products rather than an iteration also yields the same theorem; see [8]."
#               }
#             },
#             {
#               "Remark": {
#                 "label": "q:3.11",
#                 "header": "Warning",
#                 "remark": "It remains open whether a < ν⁺-closed forcing preserves the stationarity of certain subsets of Pν(H(Θ)). Formally: Suppose that ℙ is a ν⁺-closed forcing and S ⊆ Pν(H(Θ)) is a stationary set of internally club sets. Is S stationary in an extension by ℙ?"
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "Bibliography": {
#         "header": "References",
#         "entries": [
#           {
#             "key": "1",
#             "formatted_entry": "U. Abraham, Aronszajn trees on ℵ₂ and ℵ₃, Ann. Pure Appl. Logic 24 (1983), no. 3, 213–230."
#           },
#           {
#             "key": "2",
#             "formatted_entry": "J. Cummings, Iterated forcing and elementary embeddings, Handbook of set theory, M. Foreman and A. Kanamori (eds.), Springer, Dordrecht, 2010, pp. 775–883."
#           },
#           {
#             "key": "3",
#             "formatted_entry": "J. Cummings and M. Foreman, The tree property, Adv. Math. 133 (1998), no. 1, 1–32."
#           },
#           {
#             "key": "4",
#             "formatted_entry": "M. Foreman and S. Todorcevic, A new Löwenheim-Skolem theorem, Trans. Amer. Math. Soc. 357 (2005), no. 5, 1693–1715."
#           },
#           {
#             "key": "5",
#             "formatted_entry": "S. Fuchino and A. O. M. Rodrigues, Reflection principles, generic large cardinals, and the continuum problem, Symposium on Advances in Mathematical Logic, Springer, 2018, pp. 1–25."
#           },
#           {
#             "key": "6",
#             "formatted_entry": "L. Harrington and S. Shelah, Some exact equiconsistency results in set theory, Notre Dame J. Form. Log. 26 (1985), no. 2, 178–188."
#           },
#           {
#             "key": "7",
#             "formatted_entry": "H. Jakob, Disjoint stationary sequences on an interval of cardinals, arXiv:2309.01986, 2023."
#           },
#           {
#             "key": "8",
#             "formatted_entry": "H. Jakob, Variants of Mitchell forcing, Ph.D. thesis, University of Freiburg, 2023-2025."
#           },
#           {
#             "key": "9",
#             "formatted_entry": "T. Jech, Set Theory, Springer Monographs in Mathematics, Springer, Berlin, the third millennium, revised and expanded edition, 2003."
#           },
#           {
#             "key": "10",
#             "formatted_entry": "J. Krueger, Internally club and approachable, Adv. Math. 213 (2007), no. 2, 734–740."
#           },
#           {
#             "key": "11",
#             "formatted_entry": "J. Krueger, A general Mitchell style iteration, MLQ Math. Log. Q. 54 (2008), no. 6, 641–651."
#           },
#           {
#             "key": "12",
#             "formatted_entry": "J. Krueger, Some applications of mixed support iterations, Ann. Pure Appl. Logic 158 (2009), no. 1-2, 40–57."
#           },
#           {
#             "key": "13",
#             "formatted_entry": "M. Levine, On disjoint stationary sequences. Pac. J. Math. 332 (2024), no. 1, 147–165."
#           },
#           {
#             "key": "14",
#             "formatted_entry": "S. Unger, Fragility and indestructibility II, Ann. Pure Appl. Logic 166 (2015), no. 11, 1110–1122."
#           },
#           {
#             "key": "15",
#             "formatted_entry": "T. Usuba, The approximation property and the chain condition, RIMS Kokyuroku 1985 (2014), 130–134."
#           },
#           {
#             "key": "16",
#             "formatted_entry": "Y. Yoshinobu, The *-variation of the Banach–Mazur game and forcing axioms, Ann. Pure Appl. Logic 168 (2017), no. 6, 1335–1359."
#           }
#         ]
#       }
#     }
#   ]
# }

# %%
# Validate the output json against the schema
import jsonschema
from jsonschema import validate
def validate_json(json_data, schema):
    try:
        validate(instance=json_data, schema=schema)
        print("JSON is valid.")
    except jsonschema.exceptions.ValidationError as err:
        print("JSON is invalid.")
        print(err)

validate_json(json.loads(paper_json_out), schema)
# Out:
# JSON is invalid.
# {'Bibliography': {'header': 'References', 'entries': [{'key': '1', 'formatted_entry': 'U. Abraham, Aronszajn trees on ℵ₂ and ℵ₃, Ann. Pure Appl. Logic 24 (1983), no. 3, 213–230.'}, {'key': '2', 'formatted_entry': 'J. Cummings, Iterated forcing and elementary embeddings, Handbook of set theory, M. Foreman and A. Kanamori (eds.), Springer, Dordrecht, 2010, pp. 775–883.'}, {'key': '3', 'formatted_entry': 'J. Cummings and M. Foreman, The tree property, Adv. Math. 133 (1998), no. 1, 1–32.'}, {'key': '4', 'formatted_entry': 'M. Foreman and S. Todorcevic, A new Löwenheim-Skolem theorem, Trans. Amer. Math. Soc. 357 (2005), no. 5, 1693–1715.'}, {'key': '5', 'formatted_entry': 'S. Fuchino and A. O. M. Rodrigues, Reflection principles, generic large cardinals, and the continuum problem, Symposium on Advances in Mathematical Logic, Springer, 2018, pp. 1–25.'}, {'key': '6', 'formatted_entry': 'L. Harrington and S. Shelah, Some exact equiconsistency results in set theory, Notre Dame J. Form. Log. 26 (1985), no. 2, 178–188.'}, {'key': '7', 'formatted_entry': 'H. Jakob, Disjoint stationary sequences on an interval of cardinals, arXiv:2309.01986, 2023.'}, {'key': '8', 'formatted_entry': 'H. Jakob, Variants of Mitchell forcing, Ph.D. thesis, University of Freiburg, 2023-2025.'}, {'key': '9', 'formatted_entry': 'T. Jech, Set Theory, Springer Monographs in Mathematics, Springer, Berlin, the third millennium, revised and expanded edition, 2003.'}, {'key': '10', 'formatted_entry': 'J. Krueger, Internally club and approachable, Adv. Math. 213 (2007), no. 2, 734–740.'}, {'key': '11', 'formatted_entry': 'J. Krueger, A general Mitchell style iteration, MLQ Math. Log. Q. 54 (2008), no. 6, 641–651.'}, {'key': '12', 'formatted_entry': 'J. Krueger, Some applications of mixed support iterations, Ann. Pure Appl. Logic 158 (2009), no. 1-2, 40–57.'}, {'key': '13', 'formatted_entry': 'M. Levine, On disjoint stationary sequences. Pac. J. Math. 332 (2024), no. 1, 147–165.'}, {'key': '14', 'formatted_entry': 'S. Unger, Fragility and indestructibility II, Ann. Pure Appl. Logic 166 (2015), no. 11, 1110–1122.'}, {'key': '15', 'formatted_entry': 'T. Usuba, The approximation property and the chain condition, RIMS Kokyuroku 1985 (2014), 130–134.'}, {'key': '16', 'formatted_entry': 'Y. Yoshinobu, The *-variation of the Banach–Mazur game and forcing axioms, Ann. Pure Appl. Logic 168 (2017), no. 6, 1335–1359.'}]}} is not valid under any of the given schemas
#
# Failed validating 'anyOf' in schema['properties']['document']['items']:
#     {'anyOf': [{'$ref': '#/$defs/Title'},
#                {'$ref': '#/$defs/Abstract'},
#                {'$ref': '#/$defs/Metadata'},
#                {'$ref': '#/$defs/Section'},
#                {'$ref': '#/$defs/Theorem'},
#                {'$ref': '#/$defs/Definition'},
#                {'$ref': '#/$defs/Remark'},
#                {'$ref': '#/$defs/LogicalStepSequence'},
#                {'$ref': '#/$defs/Paragraph'},
#                {'$ref': '#/$defs/Proof'},
#                {'$ref': '#/$defs/Figure'},
#                {'$ref': '#/$defs/Table'},
#                {'$ref': '#/$defs/Bibliography'}]}
#
# On instance['document'][7]:
#     {'Bibliography': {'header': 'References',
#                       'entries': [{'key': '1',
#                                    'formatted_entry': 'U. Abraham, '
#                                                       'Aronszajn trees on '
#                                                       'ℵ₂ and ℵ₃, Ann. '
#                                                       'Pure Appl. Logic 24 '
#                                                       '(1983), no. 3, '
#                                                       '213–230.'},
#                                   {'key': '2',
#                                    'formatted_entry': 'J. Cummings, '
#                                                       'Iterated forcing '
#                                                       'and elementary '
#                                                       'embeddings, '
#                                                       'Handbook of set '
#                                                       'theory, M. Foreman '
#                                                       'and A. Kanamori '
#                                                       '(eds.), Springer, '
#                                                       'Dordrecht, 2010, '
#                                                       'pp. 775–883.'},
#                                   {'key': '3',
#                                    'formatted_entry': 'J. Cummings and M. '
#                                                       'Foreman, The tree '
#                                                       'property, Adv. '
#                                                       'Math. 133 (1998), '
#                                                       'no. 1, 1–32.'},
#                                   {'key': '4',
#                                    'formatted_entry': 'M. Foreman and S. '
#                                                       'Todorcevic, A new '
#                                                       'Löwenheim-Skolem '
#                                                       'theorem, Trans. '
#                                                       'Amer. Math. Soc. '
#                                                       '357 (2005), no. 5, '
#                                                       '1693–1715.'},
#                                   {'key': '5',
#                                    'formatted_entry': 'S. Fuchino and A. '
#                                                       'O. M. Rodrigues, '
#                                                       'Reflection '
#                                                       'principles, generic '
#                                                       'large cardinals, '
#                                                       'and the continuum '
#                                                       'problem, Symposium '
#                                                       'on Advances in '
#                                                       'Mathematical Logic, '
#                                                       'Springer, 2018, pp. '
#                                                       '1–25.'},
#                                   {'key': '6',
#                                    'formatted_entry': 'L. Harrington and '
#                                                       'S. Shelah, Some '
#                                                       'exact '
#                                                       'equiconsistency '
#                                                       'results in set '
#                                                       'theory, Notre Dame '
#                                                       'J. Form. Log. 26 '
#                                                       '(1985), no. 2, '
#                                                       '178–188.'},
#                                   {'key': '7',
#                                    'formatted_entry': 'H. Jakob, Disjoint '
#                                                       'stationary '
#                                                       'sequences on an '
#                                                       'interval of '
#                                                       'cardinals, '
#                                                       'arXiv:2309.01986, '
#                                                       '2023.'},
#                                   {'key': '8',
#                                    'formatted_entry': 'H. Jakob, Variants '
#                                                       'of Mitchell '
#                                                       'forcing, Ph.D. '
#                                                       'thesis, University '
#                                                       'of Freiburg, '
#                                                       '2023-2025.'},
#                                   {'key': '9',
#                                    'formatted_entry': 'T. Jech, Set '
#                                                       'Theory, Springer '
#                                                       'Monographs in '
#                                                       'Mathematics, '
#                                                       'Springer, Berlin, '
#                                                       'the third '
#                                                       'millennium, revised '
#                                                       'and expanded '
#                                                       'edition, 2003.'},
#                                   {'key': '10',
#                                    'formatted_entry': 'J. Krueger, '
#                                                       'Internally club and '
#                                                       'approachable, Adv. '
#                                                       'Math. 213 (2007), '
#                                                       'no. 2, 734–740.'},
#                                   {'key': '11',
#                                    'formatted_entry': 'J. Krueger, A '
#                                                       'general Mitchell '
#                                                       'style iteration, '
#                                                       'MLQ Math. Log. Q. '
#                                                       '54 (2008), no. 6, '
#                                                       '641–651.'},
#                                   {'key': '12',
#                                    'formatted_entry': 'J. Krueger, Some '
#                                                       'applications of '
#                                                       'mixed support '
#                                                       'iterations, Ann. '
#                                                       'Pure Appl. Logic '
#                                                       '158 (2009), no. '
#                                                       '1-2, 40–57.'},
#                                   {'key': '13',
#                                    'formatted_entry': 'M. Levine, On '
#                                                       'disjoint stationary '
#                                                       'sequences. Pac. J. '
#                                                       'Math. 332 (2024), '
#                                                       'no. 1, 147–165.'},
#                                   {'key': '14',
#                                    'formatted_entry': 'S. Unger, Fragility '
#                                                       'and '
#                                                       'indestructibility '
#                                                       'II, Ann. Pure Appl. '
#                                                       'Logic 166 (2015), '
#                                                       'no. 11, 1110–1122.'},
#                                   {'key': '15',
#                                    'formatted_entry': 'T. Usuba, The '
#                                                       'approximation '
#                                                       'property and the '
#                                                       'chain condition, '
#                                                       'RIMS Kokyuroku 1985 '
#                                                       '(2014), 130–134.'},
#                                   {'key': '16',
#                                    'formatted_entry': 'Y. Yoshinobu, The '
#                                                       '*-variation of the '
#                                                       'Banach–Mazur game '
#                                                       'and forcing axioms, '
#                                                       'Ann. Pure Appl. '
#                                                       'Logic 168 (2017), '
#                                                       'no. 6, '
#                                                       '1335–1359.'}]}}

# %%
# Save the response to a file
output_path = Path(f"../results/BLMC/{paper_name}.json")
output_path.parent.mkdir(parents=True, exist_ok=True)
output_path.write_text(response.choices[0].message.content, encoding="utf-8")
# Out:
# 30529
